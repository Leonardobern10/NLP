# %% [markdown]
# #  Winston Churchill, “We Shall Fight on the Beaches”

# %%
texto = "HI have, myself, full confidence that if all do their duty, if nothing is neglected, and if the best arrangements are made, as they are being made, we shall prove ourselves once again able to defend our Island home, to ride out the storm of war, and to outlive the menace of tyranny, if necessary for years, if necessary alone. At any rate, that is what we are going to try to do. That is the resolve of His Majesty's Government-every man of them. That is the will of Parliament and the nation. The British Empire and the French Republic, linked together in their cause and in their need, will defend to the death their native soil, aiding each other like good comrades to the utmost of their strength. Even though large tracts of Europe and many old and famous States have fallen or may fall into the grip of the Gestapo and all the odious apparatus of Nazi rule, we shall not flag or fail. We shall go on to the end, we shall fight in France, we shall fight on the seas and oceans, we shall fight with growing confidence and growing strength in the air, we shall defend our Island, whatever the cost may be, we shall fight on the beaches, we shall fight on the landing grounds, we shall fight in the fields and in the streets, we shall fight in the hills; we shall never surrender, and even if, which I do not for a moment believe, this Island or a large part of it were subjugated and starving, then our Empire beyond the seas, armed and guarded by the British Fleet, would carry on the struggle, until, in God's good time, the New World, with all its power and might, steps forth to the rescue and the liberation of the old."
texto
# Out:
# "HI have, myself, full confidence that if all do their duty, if nothing is neglected, and if the best arrangements are made, as they are being made, we shall prove ourselves once again able to defend our Island home, to ride out the storm of war, and to outlive the menace of tyranny, if necessary for years, if necessary alone. At any rate, that is what we are going to try to do. That is the resolve of His Majesty's Government-every man of them. That is the will of Parliament and the nation. The British Empire and the French Republic, linked together in their cause and in their need, will defend to the death their native soil, aiding each other like good comrades to the utmost of their strength. Even though large tracts of Europe and many old and famous States have fallen or may fall into the grip of the Gestapo and all the odious apparatus of Nazi rule, we shall not flag or fail. We shall go on to the end, we shall fight in France, we shall fight on the seas and oceans, we shall figh
# ...

# %% [markdown]
# Transformando as letras do discurso em minúscula

# %%
texto = texto.lower()
texto
# Out:
# "hi have, myself, full confidence that if all do their duty, if nothing is neglected, and if the best arrangements are made, as they are being made, we shall prove ourselves once again able to defend our island home, to ride out the storm of war, and to outlive the menace of tyranny, if necessary for years, if necessary alone. at any rate, that is what we are going to try to do. that is the resolve of his majesty's government-every man of them. that is the will of parliament and the nation. the british empire and the french republic, linked together in their cause and in their need, will defend to the death their native soil, aiding each other like good comrades to the utmost of their strength. even though large tracts of europe and many old and famous states have fallen or may fall into the grip of the gestapo and all the odious apparatus of nazi rule, we shall not flag or fail. we shall go on to the end, we shall fight in france, we shall fight on the seas and oceans, we shall figh
# ...

# %% [markdown]
# Removendo as pontuações do discurso

# %%
import re
texto = re.sub('[^\w\s]', '', texto)
texto
# Out:
# 'hi have myself full confidence that if all do their duty if nothing is neglected and if the best arrangements are made as they are being made we shall prove ourselves once again able to defend our island home to ride out the storm of war and to outlive the menace of tyranny if necessary for years if necessary alone at any rate that is what we are going to try to do that is the resolve of his majestys governmentevery man of them that is the will of parliament and the nation the british empire and the french republic linked together in their cause and in their need will defend to the death their native soil aiding each other like good comrades to the utmost of their strength even though large tracts of europe and many old and famous states have fallen or may fall into the grip of the gestapo and all the odious apparatus of nazi rule we shall not flag or fail we shall go on to the end we shall fight in france we shall fight on the seas and oceans we shall fight with growing confidence 
# ...

# %% [markdown]
# Removendo as stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Paulo
# [nltk_data]     Roberto\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop = stopwords.words('english')

# %%
def remove_stopwords(x):
    x = " ".join(x for x in x.split() if x not in stop)
    return x

# %%
texto = remove_stopwords(texto)
texto
# Out:
# 'hi full confidence duty nothing neglected best arrangements made made shall prove able defend island home ride storm war outlive menace tyranny necessary years necessary alone rate going try resolve majestys governmentevery man parliament nation british empire french republic linked together cause need defend death native soil aiding like good comrades utmost strength even though large tracts europe many old famous states fallen may fall grip gestapo odious apparatus nazi rule shall flag fail shall go end shall fight france shall fight seas oceans shall fight growing confidence growing strength air shall defend island whatever cost may shall fight beaches shall fight landing grounds shall fight fields streets shall fight hills shall never surrender even moment believe island large part subjugated starving empire beyond seas armed guarded british fleet would carry struggle gods good time new world power might steps forth rescue liberation old'

# %% [markdown]
# Correção ortográfica

# %%
from textblob import TextBlob

# %%
def corrige(x):
    x = str(TextBlob(x).correct())
    return x

# %%
texto = corrige(texto)
texto
# Out:
# 'hi full confidence duty nothing neglected best arrangements made made shall prove able defend island home ride storm war outlive menace tyranny necessary years necessary alone rate going try resolve majesty governmentevery man parliament nation british empire french republic linked together cause need defend death native soil aiding like good comrades utmost strength even though large tracts europe many old famous states fallen may fall grip gestapo odious apparatus nasi rule shall flag fail shall go end shall fight france shall fight seas ocean shall fight growing confidence growing strength air shall defend island whatever cost may shall fight reaches shall fight landing grounds shall fight fields streets shall fight hills shall never surrender even moment believe island large part subjugated starving empire beyond seas armed guarded british fleet would carry struggle gods good time new world power might steps forth rescue liberation old'

# %% [markdown]
# Lematização

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Paulo
# [nltk_data]     Roberto\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Paulo
# [nltk_data]     Roberto\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from textblob import Word

# %%
def lemma(x):
    x = " ".join([Word(word).lemmatize() for word in x.split()])
    return x

# %%
texto = lemma(texto)
texto
# Out:
# 'hi full confidence duty nothing neglected best arrangement made made shall prove able defend island home ride storm war outlive menace tyranny necessary year necessary alone rate going try resolve majesty governmentevery man parliament nation british empire french republic linked together cause need defend death native soil aiding like good comrade utmost strength even though large tract europe many old famous state fallen may fall grip gestapo odious apparatus nasi rule shall flag fail shall go end shall fight france shall fight sea ocean shall fight growing confidence growing strength air shall defend island whatever cost may shall fight reach shall fight landing ground shall fight field street shall fight hill shall never surrender even moment believe island large part subjugated starving empire beyond sea armed guarded british fleet would carry struggle god good time new world power might step forth rescue liberation old'

# %% [markdown]
# Explorando os dados

# %%
from nltk.probability import FreqDist
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Paulo
# [nltk_data]     Roberto\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Quantidade de caracteres

# %%
len(texto)
# Out:
# 938

# %% [markdown]
# Quantidade de palavras

# %%
len(texto.split())
# Out:
# 144

# %% [markdown]
# Frequencia das palavras

# %%
freq_palavras = nltk.FreqDist(texto.split())
freq_palavras
# Out:
# FreqDist({'shall': 12, 'fight': 7, 'defend': 3, 'island': 3, 'confidence': 2, 'made': 2, 'necessary': 2, 'british': 2, 'empire': 2, 'good': 2, ...})

# %% [markdown]
# Frequencia das palavras em ordem

# %%
freq_palavras_ordem = sorted(freq_palavras, key = freq_palavras.__getitem__, reverse = True)
freq_palavras_ordem
# Out:
# ['shall',
#  'fight',
#  'defend',
#  'island',
#  'confidence',
#  'made',
#  'necessary',
#  'british',
#  'empire',
#  'good',
#  'strength',
#  'even',
#  'large',
#  'old',
#  'may',
#  'sea',
#  'growing',
#  'hi',
#  'full',
#  'duty',
#  'nothing',
#  'neglected',
#  'best',
#  'arrangement',
#  'prove',
#  'able',
#  'home',
#  'ride',
#  'storm',
#  'war',
#  'outlive',
#  'menace',
#  'tyranny',
#  'year',
#  'alone',
#  'rate',
#  'going',
#  'try',
#  'resolve',
#  'majesty',
#  'governmentevery',
#  'man',
#  'parliament',
#  'nation',
#  'french',
#  'republic',
#  'linked',
#  'together',
#  'cause',
#  'need',
#  'death',
#  'native',
#  'soil',
#  'aiding',
#  'like',
#  'comrade',
#  'utmost',
#  'though',
#  'tract',
#  'europe',
#  'many',
#  'famous',
#  'state',
#  'fallen',
#  'fall',
#  'grip',
#  'gestapo',
#  'odious',
#  'apparatus',
#  'nasi',
#  'rule',
#  'flag',
#  'fail',
#  'go',
#  'end',
#  'france',
#  'ocean',
#  'air',
#  'whatever',
#  'cost',
# ...

# %%
freq_dist = nltk.FreqDist(texto.split())
freq_dist.plot(20, cumulative = False)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# Wordcloud - Destaque das principais palavras do discurso

# %%
from wordcloud import WordCloud
wcloud = WordCloud().generate_from_frequencies(freq_dist)

import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation = 'bilinear')
plt.axis("off") 
(-0.5, 399.5, 199.5, -0.5) 
plt.show()
